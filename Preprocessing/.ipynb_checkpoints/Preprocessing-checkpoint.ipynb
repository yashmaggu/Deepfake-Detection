# %%
#To get the average frame count 
import json
import glob
import numpy as np
import cv2
import copy

video_files =  glob.glob('../Dataset-Small/real/*.mp4')

frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [469, 303, 350, 529, 326, 459, 534, 479, 464, 520]
# Total number of videos:  10
# Average frame per video: 443.3

# %%
# !pip3 install face_recognition
# !mkdir '/Face_Crop'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Click>=6.0 (from face_recognition)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dlib>=19.7 (from face_recognition)
#   Using cached dlib-19.24.2.tar.gz (11.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from face_recognition) (1.21.6)
# Collecting Pillow (from face_recognition)
#   Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl.metadata (9.7 kB)
# Requirement already satisfied: colorama in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from Click>=6.0->face_recognition) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata->Click>=6.0->face_recognition) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata->Click>=6.0->face_recognition) (4.7.1)
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): finished with status 'error'
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   Building wheel for dlib (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [74 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Building extension for Python 3.7.0 (v3.7.0:1bf9cc5093, Jun 27 2018, 04:59:51) [MSC v.1914 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\PRANAY\AppData\Local\Temp\pip-install-3d9n1mdj\dlib_b1773afe28f34f5dafcb3fefda35d8d7\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\PRANAY\AppData\Local\Temp\pip-install-3d9n1mdj\dlib_b1773afe28f34f5dafcb3fefda35d8d7\build\lib.win-amd64-cpython-37 -DPYTHON_EXECUTABLE=c:\users\pranay\appdata\local\programs\python\python37\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\PRANAY\AppData\Local\Temp\pip-install-3d9n1mdj\dlib_b1773afe28f34f5dafcb3fefda35d8d7\build\lib.win-amd64-cpython-37 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:5 (message):
#
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#     You must use Visual Studio to build a python extension on windows.  If you
#     are getting this error it means you have not installed Visual C++.  Note
#     that there are many flavors of Visual Studio, like Visual Studio for C#
#     development.  You need to install Visual Studio for C++.
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#   -- Configuring incomplete, errors occurred!
#   C:\Users\PRANAY\AppData\Local\Temp\pip-install-3d9n1mdj\dlib_b1773afe28f34f5dafcb3fefda35d8d7\setup.py:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Traceback (most recent call last):
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 252, in build_wheel
#       metadata_directory)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\build_meta.py", line 417, in build_wheel
#       wheel_directory, config_settings)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\build_meta.py", line 401, in _build_with_temp_dir
#       self.run_setup()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\build_meta.py", line 338, in run_setup
#       exec(code, locals())
#     File "<string>", line 250, in <module>
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\__init__.py", line 107, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 368, in run
#       self.run_command("build")
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#       self.run_command(cmd_name)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-qngax1m6\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "<string>", line 130, in run
#     File "<string>", line 167, in build_extension
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\subprocess.py", line 328, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-3d9n1mdj\\dlib_b1773afe28f34f5dafcb3fefda35d8d7\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-3d9n1mdj\\dlib_b1773afe28f34f5dafcb3fefda35d8d7\\build\\lib.win-amd64-cpython-37', '-DPYTHON_EXECUTABLE=c:\\users\\pranay\\appdata\\local\\programs\\python\\python37\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-3d9n1mdj\\dlib_b1773afe28f34f5dafcb3fefda35d8d7\\build\\lib.win-amd64-cpython-37', '-A', 'x64']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects
# The syntax of the command is incorrect.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16444\4220878322.py in <module>
#       1 get_ipython().system('pip3 install face_recognition')
#       2 get_ipython().system("mkdir '/Face_Crop'")
# ----> 3 import torch
#       4 import torchvision
#       5 from torchvision import transforms
#
# ModuleNotFoundError: No module named 'torch'

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
            


# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      if(idx <= 150): #Extract only first 150 frames from video with cropped to face
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      -------------------------------------- 100.1/100.1 MB 1.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting Click>=6.0 (from face_recognition)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dlib>=19.7 (from face_recognition)
#   Downloading dlib-19.24.2.tar.gz (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 3.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from face_recognition) (1.21.6)
# Collecting Pillow (from face_recognition)
#   Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl.metadata (9.7 kB)
# Requirement already satisfied: colorama in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from Click>=6.0->face_recognition) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata->Click>=6.0->face_recognition) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata->Click>=6.0->face_recognition) (4.7.1)
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Building wheels for collected packages: dlib, face-recognition-models
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): finished with status 'error'
#   Building wheel for face-recognition-models (pyproject.toml): started
#   Building wheel for face-recognition-models (pyproject.toml): finished with status 'done'
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566183 sha256=7c3bceea55572a5919275cbf42deb6092236de986caa41023ac95389771f60f3
#   Stored in directory: c:\users\pranay\appdata\local\pip\cache\wheels\d6\81\3c\884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   Building wheel for dlib (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [74 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Building extension for Python 3.7.0 (v3.7.0:1bf9cc5093, Jun 27 2018, 04:59:51) [MSC v.1914 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\PRANAY\AppData\Local\Temp\pip-install-rgubzdsz\dlib_c7f37dd4675941fcbb58286c6123ceb0\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\PRANAY\AppData\Local\Temp\pip-install-rgubzdsz\dlib_c7f37dd4675941fcbb58286c6123ceb0\build\lib.win-amd64-cpython-37 -DPYTHON_EXECUTABLE=c:\users\pranay\appdata\local\programs\python\python37\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\PRANAY\AppData\Local\Temp\pip-install-rgubzdsz\dlib_c7f37dd4675941fcbb58286c6123ceb0\build\lib.win-amd64-cpython-37 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:5 (message):
#
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#     You must use Visual Studio to build a python extension on windows.  If you
#     are getting this error it means you have not installed Visual C++.  Note
#     that there are many flavors of Visual Studio, like Visual Studio for C#
#     development.  You need to install Visual Studio for C++.
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#   -- Configuring incomplete, errors occurred!
#   C:\Users\PRANAY\AppData\Local\Temp\pip-install-rgubzdsz\dlib_c7f37dd4675941fcbb58286c6123ceb0\setup.py:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Traceback (most recent call last):
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 252, in build_wheel
#       metadata_directory)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\build_meta.py", line 417, in build_wheel
#       wheel_directory, config_settings)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\build_meta.py", line 401, in _build_with_temp_dir
#       self.run_setup()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\build_meta.py", line 338, in run_setup
#       exec(code, locals())
#     File "<string>", line 250, in <module>
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\__init__.py", line 107, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 368, in run
#       self.run_command("build")
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#       self.run_command(cmd_name)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\PRANAY\AppData\Local\Temp\pip-build-env-um1e5bfx\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "<string>", line 130, in run
#     File "<string>", line 167, in build_extension
#     File "c:\users\pranay\appdata\local\programs\python\python37\lib\subprocess.py", line 328, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-rgubzdsz\\dlib_c7f37dd4675941fcbb58286c6123ceb0\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-rgubzdsz\\dlib_c7f37dd4675941fcbb58286c6123ceb0\\build\\lib.win-amd64-cpython-37', '-DPYTHON_EXECUTABLE=c:\\users\\pranay\\appdata\\local\\programs\\python\\python37\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\PRANAY\\AppData\\Local\\Temp\\pip-install-rgubzdsz\\dlib_c7f37dd4675941fcbb58286c6123ceb0\\build\\lib.win-amd64-cpython-37', '-A', 'x64']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects

# %%
create_face_videos(video_files,'/Face_Crop/')
